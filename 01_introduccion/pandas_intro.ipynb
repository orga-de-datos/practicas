# %% [markdown]
# # Clase 1 - Introducción a pandas

# %% [markdown]
# En este notebook vamos a ver una introducción a los comandos iniciales de la biblioteca pandas para Python. [Pandas](https://pandas.pydata.org) es una biblioteca sponsoreada por [NumFOCUS](https://numfocus.org/sponsored-projects).
#
# La descripción en su página la define como:
#
# > pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.

# %% [markdown]
# # Estructuras de datos

# %% [markdown]
# Dos estructuras fundamentales dentro de pandas son Series y DataFrames. Los dataframes son tablas de datos. Cada columna es una Series. Revisar la [documentacion](https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html#).
#
# Para comenzar, vamos a crear nuestro primer DataFrame a partir de un archivo CSV que contiene un [dataset sobre superhéroes](https://www.kaggle.com/claudiodavi/superhero-set/home).

# %%
from collections import Counter
import requests

# %% [markdown]
# Empezamos por descargarlo del drive de la materia.

# %%
with requests.get(
    "https://docs.google.com/spreadsheets/d/1nuJAaaH_IP8Q80CsyS940EVaePkbmqhN3vlorDxYMnA/export?format=csv"
) as r, open("superheroes.csv", "wb") as f:
    for chunk in r.iter_content():
        f.write(chunk)

# %%
import pandas as pd

df = pd.read_csv("superheroes.csv")
# pd.read_csv("https://docs.google.com/spreadsheets/d/1nuJAaaH_IP8Q80CsyS940EVaePkbmqhN3vlorDxYMnA/export?format=csv")

# %% [markdown]
# También podemos crear dataframes desde listas, diccionarios y otras estructuras.

# %% [markdown]
# ## Inspeccionando un dataframe

# %% [markdown]
# A los items individuales se los suele llamar _samples_ y a sus propiedades _features_.

# %%
# vemos los primeros elementos o samples
df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0

# %%
df.tail()
# Out:
#                 name  Gender Eye color            Race        Hair color  \
# 729  Yellowjacket II  Female      blue           Human  Strawberry Blond
# 730             Ymir    Male     white     Frost Giant           No Hair
# 731             Yoda    Male     brown  Yoda's species             White
# 732          Zatanna  Female      blue           Human             Black
# 733             Zoom    Male       red               -             Brown
#
#      Height      Publisher Skin color Alignment  Weight
# 729   165.0  Marvel Comics          -      good    52.0
# 730   304.8  Marvel Comics      white      good   -99.0
# 731    66.0   George Lucas      green      good    17.0
# 732   170.0      DC Comics          -      good    57.0
# 733   185.0      DC Comics          -       bad    81.0

# %%
df.sample()
# Out:
#            name Gender Eye color Race Hair color  Height    Publisher  \
# 363  Jim Powell   Male         -    -          -   -99.0  ABC Studios
#
#     Skin color Alignment  Weight
# 363          -      good   -99.0

# %%
df.sample(10)
# Out:
#                  name  Gender     Eye color                Race Hair color  \
# 404          Leonardo    Male          blue              Mutant    No Hair
# 366  John Constantine    Male          blue               Human      Blond
# 344         Iron Fist    Male          blue               Human      Blond
# 206        Darth Maul    Male  yellow / red  Dathomirian Zabrak          -
# 93       Black Abbott    Male           red                   -      Black
# 725              X-23  Female         green      Mutant / Clone      Black
# 499         Offspring    Male             -                   -          -
# 252             Faora  Female             -          Kryptonian          -
# 418    Luke Skywalker    Male          blue               Human      Blond
# 507         Overtkill    Male             -                   -          -
#
#      Height       Publisher   Skin color Alignment  Weight
# 404   -99.0  IDW Publishing        green      good   -99.0
# 366   183.0       DC Comics            -      good   -99.0
# 344   180.0   Marvel Comics            -      good    79.0
# 206   170.0    George Lucas  red / black       bad   -99.0
# 93    -99.0   Marvel Comics            -       bad   -99.0
# 725   155.0   Marvel Comics            -      good    50.0
# 499   -99.0       DC Comics            -      good   -99.0
# 252   -99.0       DC Comics            -       bad   -99.0
# 418   168.0    George Lucas            -      good    77.0
# 507   -99.0    Image Comics            -       bad   -99.0

# %% [markdown]
# La estructura de un dataset se puede obtener mediante _shape_. Devuelve el número de samples y el número de features.

# %%
df.shape
# Out:
# (734, 10)

# %% [markdown]
# ## Información sobre un dataframe

# %%
# descripción de cada columna e información general del dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        734 non-null    object
#  1   Gender      734 non-null    object
#  2   Eye color   734 non-null    object
#  3   Race        734 non-null    object
#  4   Hair color  734 non-null    object
#  5   Height      734 non-null    float64
#  6   Publisher   719 non-null    object
#  7   Skin color  734 non-null    object
#  8   Alignment   734 non-null    object
#  9   Weight      732 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 57.5+ KB

# %% [markdown]
# La última columna, `Dtype` nos dice qué tipo de dato interpreta pandas que es esa columna. Las columnas de tipo `str` son interpretadas con `dtype` del tipo `object`.

# %%
# resumen estadístico de las columnas numéricas
df.describe()
# Out:
#            Height      Weight
# count  734.000000  732.000000
# mean   102.254087   43.855191
# std    139.624543  130.823733
# min    -99.000000  -99.000000
# 25%    -99.000000  -99.000000
# 50%    175.000000   62.000000
# 75%    185.000000   90.000000
# max    975.000000  900.000000

# %%
# si queremos ver la cantidad de nulos en cada columna
# creamos una máscara binaria y la sumamos
df.isnull().sum()
# Out:
# name           0
# Gender         0
# Eye color      0
# Race           0
# Hair color     0
# Height         0
# Publisher     15
# Skin color     0
# Alignment      0
# Weight         2
# dtype: int64

# %% [markdown]
# # Cómo obtener valores que nos interesan

# %% [markdown]
# ## Por índices

# %%
df.index
# Out:
# RangeIndex(start=0, stop=734, step=1)

# %%
df = df.set_index('name')
df
# Out:
#                  Gender Eye color               Race        Hair color  \
# name
# A-Bomb             Male    yellow              Human           No Hair
# Abe Sapien         Male      blue      Icthyo Sapien           No Hair
# Abin Sur           Male      blue            Ungaran           No Hair
# Abomination        Male     green  Human / Radiation           No Hair
# Abraxas            Male      blue      Cosmic Entity             Black
# ...                 ...       ...                ...               ...
# Yellowjacket II  Female      blue              Human  Strawberry Blond
# Ymir               Male     white        Frost Giant           No Hair
# Yoda               Male     brown     Yoda's species             White
# Zatanna          Female      blue              Human             Black
# Zoom               Male       red                  -             Brown
#
#                  Height          Publisher Skin color Alignment  Weight
# name
# A-Bomb            203.0      Marvel Comics          -      good   441.0
# Abe Sapien        191.0  Dark Horse Comics       blue      good    65.0
# Abin Sur          185.0          DC Comics        red      good    90.0
# Abomination       203.0      Marvel Comics          -       bad   441.0
# Abraxas           -99.0      Marvel Comics          -       bad   -99.0
# ...                 ...                ...        ...       ...     ...
# Yellowjacket II   165.0      Marvel Comics          -      good    52.0
# Ymir              304.8      Marvel Comics      white      good   -99.0
# Yoda               66.0       George Lucas      green      good    17.0
# Zatanna           170.0          DC Comics          -      good    57.0
# Zoom              185.0          DC Comics          -       bad    81.0
#
# [734 rows x 9 columns]

# %%
df.index
# Out:
# Index(['A-Bomb', 'Abe Sapien', 'Abin Sur', 'Abomination', 'Abraxas',
#        'Absorbing Man', 'Adam Monroe', 'Adam Strange', 'Agent 13', 'Agent Bob',
#        ...
#        'Wyatt Wingfoot', 'X-23', 'X-Man', 'Yellow Claw', 'Yellowjacket',
#        'Yellowjacket II', 'Ymir', 'Yoda', 'Zatanna', 'Zoom'],
#       dtype='object', name='name', length=734)

# %%
hero = df.loc['Aurora']

hero
# Out:
# Gender               Female
# Eye color              blue
# Race                 Mutant
# Hair color            Black
# Height                  180
# Publisher     Marvel Comics
# Skin color                -
# Alignment              good
# Weight                   63
# Name: Aurora, dtype: object

# %%
hero = df.iloc[55]

hero
# Out:
# Gender               Female
# Eye color              blue
# Race                 Mutant
# Hair color            Black
# Height                  180
# Publisher     Marvel Comics
# Skin color                -
# Alignment              good
# Weight                   63
# Name: Aurora, dtype: object

# %%
heroes = df.loc['Aurora':'Banshee']

heroes
# Out:
#          Gender Eye color      Race        Hair color  Height      Publisher  \
# name
# Aurora   Female      blue    Mutant             Black   180.0  Marvel Comics
# Azazel     Male    yellow  Neyaphem             Black   183.0  Marvel Comics
# Azrael     Male     brown     Human             Black   -99.0      DC Comics
# Aztar      Male         -         -                 -   -99.0      DC Comics
# Bane       Male         -     Human                 -   203.0      DC Comics
# Banshee    Male     green     Human  Strawberry Blond   183.0  Marvel Comics
#
#         Skin color Alignment  Weight
# name
# Aurora           -      good    63.0
# Azazel         red       bad    67.0
# Azrael           -      good   -99.0
# Aztar            -      good   -99.0
# Bane             -       bad   180.0
# Banshee          -      good    77.0

# %%
heroes = df.iloc[55:60]

heroes
# Out:
#         Gender Eye color      Race Hair color  Height      Publisher  \
# name
# Aurora  Female      blue    Mutant      Black   180.0  Marvel Comics
# Azazel    Male    yellow  Neyaphem      Black   183.0  Marvel Comics
# Azrael    Male     brown     Human      Black   -99.0      DC Comics
# Aztar     Male         -         -          -   -99.0      DC Comics
# Bane      Male         -     Human          -   203.0      DC Comics
#
#        Skin color Alignment  Weight
# name
# Aurora          -      good    63.0
# Azazel        red       bad    67.0
# Azrael          -      good   -99.0
# Aztar           -      good   -99.0
# Bane            -       bad   180.0

# %% [markdown]
# ## Obtener columnas

# %%
df.Race
# Out:
# name
# A-Bomb                         Human
# Abe Sapien             Icthyo Sapien
# Abin Sur                     Ungaran
# Abomination        Human / Radiation
# Abraxas                Cosmic Entity
#                          ...
# Yellowjacket II                Human
# Ymir                     Frost Giant
# Yoda                  Yoda's species
# Zatanna                        Human
# Zoom                               -
# Name: Race, Length: 734, dtype: object

# %%
df['Race']
# Out:
# name
# A-Bomb                         Human
# Abe Sapien             Icthyo Sapien
# Abin Sur                     Ungaran
# Abomination        Human / Radiation
# Abraxas                Cosmic Entity
#                          ...
# Yellowjacket II                Human
# Ymir                     Frost Giant
# Yoda                  Yoda's species
# Zatanna                        Human
# Zoom                               -
# Name: Race, Length: 734, dtype: object

# %% [markdown]
# ## Obtener un subconjunto de columnas

# %%
df[['Race', 'Skin color']]
# Out:
#                               Race Skin color
# name
# A-Bomb                       Human          -
# Abe Sapien           Icthyo Sapien       blue
# Abin Sur                   Ungaran        red
# Abomination      Human / Radiation          -
# Abraxas              Cosmic Entity          -
# ...                            ...        ...
# Yellowjacket II              Human          -
# Ymir                   Frost Giant      white
# Yoda                Yoda's species      green
# Zatanna                      Human          -
# Zoom                             -          -
#
# [734 rows x 2 columns]

# %% [markdown]
# ## Obtener filas

# %%
piel_azul = df['Skin color'] == 'blue'

# %%
piel_azul.head()
# Out:
# name
# A-Bomb         False
# Abe Sapien      True
# Abin Sur       False
# Abomination    False
# Abraxas        False
# Name: Skin color, dtype: bool

# %% [markdown]
# Si ahora queremos filtrar y quedarnos solamente con los datos que cumplen la condición:

# %%
df[df['Skin color'] == 'blue']
# Out:
#               Gender                Eye color            Race    Hair color  \
# name
# Abe Sapien      Male                     blue   Icthyo Sapien       No Hair
# Archangel       Male                     blue          Mutant         Blond
# Beast           Male                     blue          Mutant          Blue
# Copycat       Female                      red          Mutant         White
# Dr Manhattan    Male                    white  Human / Cosmic       No Hair
# Killer Frost  Female                     blue           Human         Blond
# Mystique      Female  yellow (without irises)          Mutant  Red / Orange
# Nebula        Female                     blue       Luphomoid       No Hair
# Shadow Lass   Female                    black        Talokite         Black
#
#               Height          Publisher Skin color Alignment  Weight
# name
# Abe Sapien     191.0  Dark Horse Comics       blue      good    65.0
# Archangel      183.0      Marvel Comics       blue      good    68.0
# Beast          180.0      Marvel Comics       blue      good   181.0
# Copycat        183.0      Marvel Comics       blue   neutral    67.0
# Dr Manhattan   -99.0          DC Comics       blue      good   -99.0
# Killer Frost   -99.0          DC Comics       blue       bad   -99.0
# Mystique       178.0      Marvel Comics       blue       bad    54.0
# Nebula         185.0      Marvel Comics       blue       bad    83.0
# Shadow Lass    173.0          DC Comics       blue      good    54.0

# %% [markdown]
# ## Múltiples condiciones

# %%
df[(df['Skin color'] == 'blue') & (df['Publisher'] == 'Marvel Comics')]
# Out:
#            Gender                Eye color       Race    Hair color  Height  \
# name
# Archangel    Male                     blue     Mutant         Blond   183.0
# Beast        Male                     blue     Mutant          Blue   180.0
# Copycat    Female                      red     Mutant         White   183.0
# Mystique   Female  yellow (without irises)     Mutant  Red / Orange   178.0
# Nebula     Female                     blue  Luphomoid       No Hair   185.0
#
#                Publisher Skin color Alignment  Weight
# name
# Archangel  Marvel Comics       blue      good    68.0
# Beast      Marvel Comics       blue      good   181.0
# Copycat    Marvel Comics       blue   neutral    67.0
# Mystique   Marvel Comics       blue       bad    54.0
# Nebula     Marvel Comics       blue       bad    83.0

# %%
df[(df['Skin color'] == 'blue') | (df['Skin color'] == 'green')].sample(10)
# Out:
#                    Gender Eye color           Race Hair color  Height  \
# name
# Donatello            Male     green         Mutant    No Hair   -99.0
# Mantis             Female     green     Human-Kree      Black   168.0
# Nebula             Female      blue      Luphomoid    No Hair   185.0
# Gamora             Female    yellow  Zen-Whoberian      Black   183.0
# Copycat            Female       red         Mutant      White   183.0
# Abe Sapien           Male      blue  Icthyo Sapien    No Hair   191.0
# Shadow Lass        Female     black       Talokite      Black   173.0
# Martian Manhunter    Male       red        Martian    No Hair   201.0
# Poison Ivy         Female     green          Human        Red   168.0
# Swamp Thing          Male       red  God / Eternal    No Hair   -99.0
#
#                            Publisher Skin color Alignment  Weight
# name
# Donatello             IDW Publishing      green      good   -99.0
# Mantis                 Marvel Comics      green      good    52.0
# Nebula                 Marvel Comics       blue       bad    83.0
# Gamora                 Marvel Comics      green      good    77.0
# Copycat                Marvel Comics       blue   neutral    67.0
# Abe Sapien         Dark Horse Comics       blue      good    65.0
# Shadow Lass                DC Comics       blue      good    54.0
# Martian Manhunter          DC Comics      green      good   135.0
# Poison Ivy                 DC Comics      green       bad    50.0
# Swamp Thing                DC Comics      green       bad   -99.0

# %% [markdown]
# # Transformaciones de datos

# %% [markdown]
# ## Apply

# %% [markdown]
# Mediante apply podemos aplicar una función definida aparte a nuestro set de datos

# %%
def rate_height(height):
    if height >= 200:
        return "Tall"
    else:
        return "Not tall"

# %%
altos = df['Height'].apply(rate_height)
altos
# Out:
# name
# A-Bomb                 Tall
# Abe Sapien         Not tall
# Abin Sur           Not tall
# Abomination            Tall
# Abraxas            Not tall
#                      ...
# Yellowjacket II    Not tall
# Ymir                   Tall
# Yoda               Not tall
# Zatanna            Not tall
# Zoom               Not tall
# Name: Height, Length: 734, dtype: object

# %% [markdown]
# Aprovechamos a ver como asignar una nueva columna

# %%
df['Tallness'] = df['Height'].apply(rate_height)

# %%
df
# Out:
#                  Gender Eye color               Race        Hair color  \
# name
# A-Bomb             Male    yellow              Human           No Hair
# Abe Sapien         Male      blue      Icthyo Sapien           No Hair
# Abin Sur           Male      blue            Ungaran           No Hair
# Abomination        Male     green  Human / Radiation           No Hair
# Abraxas            Male      blue      Cosmic Entity             Black
# ...                 ...       ...                ...               ...
# Yellowjacket II  Female      blue              Human  Strawberry Blond
# Ymir               Male     white        Frost Giant           No Hair
# Yoda               Male     brown     Yoda's species             White
# Zatanna          Female      blue              Human             Black
# Zoom               Male       red                  -             Brown
#
#                  Height          Publisher Skin color Alignment  Weight  \
# name
# A-Bomb            203.0      Marvel Comics          -      good   441.0
# Abe Sapien        191.0  Dark Horse Comics       blue      good    65.0
# Abin Sur          185.0          DC Comics        red      good    90.0
# Abomination       203.0      Marvel Comics          -       bad   441.0
# Abraxas           -99.0      Marvel Comics          -       bad   -99.0
# ...                 ...                ...        ...       ...     ...
# Yellowjacket II   165.0      Marvel Comics          -      good    52.0
# Ymir              304.8      Marvel Comics      white      good   -99.0
# Yoda               66.0       George Lucas      green      good    17.0
# Zatanna           170.0          DC Comics          -      good    57.0
# Zoom              185.0          DC Comics          -       bad    81.0
#
#                  Tallness
# name
# A-Bomb               Tall
# Abe Sapien       Not tall
# Abin Sur         Not tall
# Abomination          Tall
# Abraxas          Not tall
# ...                   ...
# Yellowjacket II  Not tall
# Ymir                 Tall
# Yoda             Not tall
# Zatanna          Not tall
# Zoom             Not tall
#
# [734 rows x 10 columns]

# %% [markdown]
# ## Replace

# %% [markdown]
# Vemos por ejemplo que 'Skin color' usa '-' para indicar valores vacíos. Corrijamos esto.

# %%
df['Skin color'].replace({"-": None}, inplace=True)

# %%
df['Skin color']
# Out:
# name
# A-Bomb              None
# Abe Sapien          blue
# Abin Sur             red
# Abomination         None
# Abraxas             None
#                    ...
# Yellowjacket II     None
# Ymir               white
# Yoda               green
# Zatanna             None
# Zoom                None
# Name: Skin color, Length: 734, dtype: object

# %% [markdown]
# ## Eliminar filas con nulos

# %%
df
# Out:
#                  Gender Eye color               Race        Hair color  \
# name
# A-Bomb             Male    yellow              Human           No Hair
# Abe Sapien         Male      blue      Icthyo Sapien           No Hair
# Abin Sur           Male      blue            Ungaran           No Hair
# Abomination        Male     green  Human / Radiation           No Hair
# Abraxas            Male      blue      Cosmic Entity             Black
# ...                 ...       ...                ...               ...
# Yellowjacket II  Female      blue              Human  Strawberry Blond
# Ymir               Male     white        Frost Giant           No Hair
# Yoda               Male     brown     Yoda's species             White
# Zatanna          Female      blue              Human             Black
# Zoom               Male       red                  -             Brown
#
#                  Height          Publisher Skin color Alignment  Weight  \
# name
# A-Bomb            203.0      Marvel Comics       None      good   441.0
# Abe Sapien        191.0  Dark Horse Comics       blue      good    65.0
# Abin Sur          185.0          DC Comics        red      good    90.0
# Abomination       203.0      Marvel Comics       None       bad   441.0
# Abraxas           -99.0      Marvel Comics       None       bad   -99.0
# ...                 ...                ...        ...       ...     ...
# Yellowjacket II   165.0      Marvel Comics       None      good    52.0
# Ymir              304.8      Marvel Comics      white      good   -99.0
# Yoda               66.0       George Lucas      green      good    17.0
# Zatanna           170.0          DC Comics       None      good    57.0
# Zoom              185.0          DC Comics       None       bad    81.0
#
#                  Tallness
# name
# A-Bomb               Tall
# Abe Sapien       Not tall
# Abin Sur         Not tall
# Abomination          Tall
# Abraxas          Not tall
# ...                   ...
# Yellowjacket II  Not tall
# Ymir                 Tall
# Yoda             Not tall
# Zatanna          Not tall
# Zoom             Not tall
#
# [734 rows x 10 columns]

# %%
df = df.dropna(subset=['Skin color'])
df
# Out:
#            Gender Eye color             Race Hair color  Height  \
# name
# Abe Sapien   Male      blue    Icthyo Sapien    No Hair   191.0
# Abin Sur     Male      blue          Ungaran    No Hair   185.0
# Alien        Male         -  Xenomorph XX121    No Hair   244.0
# Apocalypse   Male       red           Mutant      Black   213.0
# Archangel    Male      blue           Mutant      Blond   183.0
# ...           ...       ...              ...        ...     ...
# Triton       Male     green          Inhuman    No Hair   188.0
# Ultron       Male       red          Android          -   206.0
# Vision       Male      gold          Android    No Hair   191.0
# Ymir         Male     white      Frost Giant    No Hair   304.8
# Yoda         Male     brown   Yoda's species      White    66.0
#
#                     Publisher Skin color Alignment  Weight  Tallness
# name
# Abe Sapien  Dark Horse Comics       blue      good    65.0  Not tall
# Abin Sur            DC Comics        red      good    90.0  Not tall
# Alien       Dark Horse Comics      black       bad   169.0      Tall
# Apocalypse      Marvel Comics       grey       bad   135.0      Tall
# Archangel       Marvel Comics       blue      good    68.0  Not tall
# ...                       ...        ...       ...     ...       ...
# Triton          Marvel Comics      green      good    86.0  Not tall
# Ultron          Marvel Comics     silver       bad   331.0      Tall
# Vision          Marvel Comics        red      good   135.0  Not tall
# Ymir            Marvel Comics      white      good   -99.0      Tall
# Yoda             George Lucas      green      good    17.0  Not tall
#
# [72 rows x 10 columns]

# %% [markdown]
# # Unir información de distintas tablas
#
# Veamos si hay razas que tengan el mismo color de piel.

# %%
df.merge(df, left_on='Skin color', right_on='Skin color')[['Race_x', 'Race_y']]
# Out:
#             Race_x          Race_y
# 0    Icthyo Sapien   Icthyo Sapien
# 1    Icthyo Sapien          Mutant
# 2    Icthyo Sapien          Mutant
# 3    Icthyo Sapien          Mutant
# 4    Icthyo Sapien  Human / Cosmic
# ..             ...             ...
# 729        Eternal         Eternal
# 730         Gungan          Gungan
# 731        Android         Android
# 732       Czarnian        Czarnian
# 733     Tamaranean      Tamaranean
#
# [734 rows x 2 columns]

# %% [markdown]
# Tenemos duplicados!

# %%
df.merge(df, left_on='Skin color', right_on='Skin color')[['Race_x', 'Race_y']]
# Out:
#             Race_x          Race_y
# 0    Icthyo Sapien   Icthyo Sapien
# 1    Icthyo Sapien          Mutant
# 2    Icthyo Sapien          Mutant
# 3    Icthyo Sapien          Mutant
# 4    Icthyo Sapien  Human / Cosmic
# ..             ...             ...
# 729        Eternal         Eternal
# 730         Gungan          Gungan
# 731        Android         Android
# 732       Czarnian        Czarnian
# 733     Tamaranean      Tamaranean
#
# [734 rows x 2 columns]

# %% [markdown]
# Tenemos que sacar los que son iguales en ambas columnas!

# %%
same_skin_color = df.merge(df, left_on='Skin color', right_on='Skin color')[
    ['Race_x', 'Race_y']
].drop_duplicates()
same_skin_color[same_skin_color.Race_x != same_skin_color.Race_y]
# Out:
#             Race_x          Race_y
# 1    Icthyo Sapien          Mutant
# 4    Icthyo Sapien  Human / Cosmic
# 5    Icthyo Sapien           Human
# 7    Icthyo Sapien       Luphomoid
# 8    Icthyo Sapien        Talokite
# ..             ...             ...
# 723      Strontian         Eternal
# 724          Human       Strontian
# 726          Human         Eternal
# 727        Eternal       Strontian
# 728        Eternal           Human
#
# [372 rows x 2 columns]

# %%
pd.merge?

# %%
df1 = pd.DataFrame({'col': [1, 2, 3], 'val': [10, 11, 12]})
df2 = pd.DataFrame({'col': [2, 3, 4], 'val': [13, 14, 15]})

# %%
df1
# Out:
#    col  val
# 0    1   10
# 1    2   11
# 2    3   12

# %%
df2
# Out:
#    col  val
# 0    2   13
# 1    3   14
# 2    4   15

# %%
pd.merge(df1, df2, how='left', left_on='col', right_on='col')
# Out:
#    col  val_x  val_y
# 0    1     10    NaN
# 1    2     11   13.0
# 2    3     12   14.0

# %%
pd.merge(df1, df2, how='inner', left_on='col', right_on='col')
# Out:
#    col  val_x  val_y
# 0    2     11     13
# 1    3     12     14

# %%
pd.merge(df1, df2, how='right', left_on='col', right_on='col')
# Out:
#    col  val_x  val_y
# 0    2   11.0     13
# 1    3   12.0     14
# 2    4    NaN     15

# %%
pd.merge(df1, df2, how='outer', left_on='col', right_on='col')
# Out:
#    col  val_x  val_y
# 0    1   10.0    NaN
# 1    2   11.0   13.0
# 2    3   12.0   14.0
# 3    4    NaN   15.0

# %%
df1.merge?

# %%
df1.join?

# %% [markdown]
# Por último, para ver los pares únicos

# %%
same_skin_color = df.merge(df, left_on='Skin color', right_on='Skin color')[
    ['Race_x', 'Race_y']
].drop_duplicates()
same_skin_color[
    (same_skin_color.Race_x != same_skin_color.Race_y)
    & (same_skin_color.Race_x > same_skin_color.Race_y)
]
# Out:
#             Race_x          Race_y
# 4    Icthyo Sapien  Human / Cosmic
# 5    Icthyo Sapien           Human
# 9           Mutant   Icthyo Sapien
# 13          Mutant  Human / Cosmic
# 14          Mutant           Human
# ..             ...             ...
# 708         Cyborg         Android
# 719         Mutant           Demon
# 722      Strontian           Human
# 723      Strontian         Eternal
# 726          Human         Eternal
#
# [186 rows x 2 columns]

# %% [markdown]
# ### Concatenar tablas

# %%
df_1 = pd.DataFrame({'col_1': range(1, 10), 'col_2': range(1, 10)})
df_2 = pd.DataFrame({'col_1': range(11, 20), 'col_2': range(11, 20)})

# %%
df_1.pipe(len)
# Out:
# 9

# %%
df_2.pipe(len)
# Out:
# 9

# %%
df_1.head()
# Out:
#    col_1  col_2
# 0      1      1
# 1      2      2
# 2      3      3
# 3      4      4
# 4      5      5

# %%
df_2.head()
# Out:
#    col_1  col_2
# 0     11     11
# 1     12     12
# 2     13     13
# 3     14     14
# 4     15     15

# %%
df_concat = pd.concat([df_1, df_2])
df_concat
# Out:
#    col_1  col_2
# 0      1      1
# 1      2      2
# 2      3      3
# 3      4      4
# 4      5      5
# 5      6      6
# 6      7      7
# 7      8      8
# 8      9      9
# 0     11     11
# 1     12     12
# 2     13     13
# 3     14     14
# 4     15     15
# 5     16     16
# 6     17     17
# 7     18     18
# 8     19     19

# %%
df_concat.pipe(len)
# Out:
# 18

# %% [markdown]
# # Agrupaciones

# %% [markdown]
# ## Groupby

# %%
# queremos ver los nombres
df = df.reset_index()

# %%
df
# Out:
#           name Gender Eye color             Race Hair color  Height  \
# 0   Abe Sapien   Male      blue    Icthyo Sapien    No Hair   191.0
# 1     Abin Sur   Male      blue          Ungaran    No Hair   185.0
# 2        Alien   Male         -  Xenomorph XX121    No Hair   244.0
# 3   Apocalypse   Male       red           Mutant      Black   213.0
# 4    Archangel   Male      blue           Mutant      Blond   183.0
# ..         ...    ...       ...              ...        ...     ...
# 67      Triton   Male     green          Inhuman    No Hair   188.0
# 68      Ultron   Male       red          Android          -   206.0
# 69      Vision   Male      gold          Android    No Hair   191.0
# 70        Ymir   Male     white      Frost Giant    No Hair   304.8
# 71        Yoda   Male     brown   Yoda's species      White    66.0
#
#             Publisher Skin color Alignment  Weight  Tallness
# 0   Dark Horse Comics       blue      good    65.0  Not tall
# 1           DC Comics        red      good    90.0  Not tall
# 2   Dark Horse Comics      black       bad   169.0      Tall
# 3       Marvel Comics       grey       bad   135.0      Tall
# 4       Marvel Comics       blue      good    68.0  Not tall
# ..                ...        ...       ...     ...       ...
# 67      Marvel Comics      green      good    86.0  Not tall
# 68      Marvel Comics     silver       bad   331.0      Tall
# 69      Marvel Comics        red      good   135.0  Not tall
# 70      Marvel Comics      white      good   -99.0      Tall
# 71       George Lucas      green      good    17.0  Not tall
#
# [72 rows x 11 columns]

# %%
df.groupby("Race")

# %%
df.groupby("Race").agg(list)
# Out:
#                                                                  name  \
# Race
# -                                           [Kool-Aid Man, Man-Thing]
# Alien                      [Ardina, Century, Evilhawk, Silver Surfer]
# Android                     [Brainiac, K-2SO, T-1000, Ultron, Vision]
# Bizarro                                                     [Bizarro]
# Bolovaxian                                                  [Kilowog]
# Cosmic Entity                                       [Living Tribunal]
# Cyborg                                                          [T-X]
# Czarnian                                                       [Lobo]
# Dathomirian Zabrak                                       [Darth Maul]
# Demon                                             [Blackout, Etrigan]
# Eternal                                                      [Thanos]
# Frost Giant                                                    [Ymir]
# God / Eternal                          [Spectre, Swamp Thing, Trigon]
# Gungan                                                [Jar Jar Binks]
# Human               [Beast Boy, Domino, Joker, Killer Frost, Klaw,...
# Human / Altered                                  [Drax the Destroyer]
# Human / Cosmic                                   [Dr Manhattan, Nova]
# Human / Radiation                      [Captain Atom, Hulk, Red Hulk]
# Human-Kree                                                   [Mantis]
# Icthyo Sapien                                            [Abe Sapien]
# Inhuman                                                      [Triton]
# Kaiju                                                      [Godzilla]
# Kakarantharaian                                       [Fin Fang Foom]
# Korugaran                                                  [Sinestro]
# Luphomoid                                                    [Nebula]
# Martian                                           [Martian Manhunter]
# Metahuman                                               [Killer Croc]
# Mutant              [Apocalypse, Archangel, Beast, Blink, Copycat,...
# New God                                       [Darkseid, Steppenwolf]
# Neyaphem                                                     [Azazel]
# Rodian                                                       [Greedo]
# Strontian                                                 [Gladiator]
# Talokite                                                [Shadow Lass]
# Tamaranean                                                 [Starfire]
# Ungaran                                                    [Abin Sur]
# Xenomorph XX121                                               [Alien]
# Yoda's species                                                 [Yoda]
# Zen-Whoberian                                                [Gamora]
#
#                                                                Gender  \
# Race
# -                                                        [Male, Male]
# Alien                                      [Female, Male, Male, Male]
# Android                                [Male, Male, Male, Male, Male]
# Bizarro                                                        [Male]
# Bolovaxian                                                     [Male]
# Cosmic Entity                                                     [-]
# Cyborg                                                       [Female]
# Czarnian                                                       [Male]
# Dathomirian Zabrak                                             [Male]
# Demon                                                    [Male, Male]
# Eternal                                                        [Male]
# Frost Giant                                                    [Male]
# God / Eternal                                      [Male, Male, Male]
# Gungan                                                         [Male]
# Human               [Male, Female, Male, Female, Male, Female, Mal...
# Human / Altered                                                [Male]
# Human / Cosmic                                         [Male, Female]
# Human / Radiation                                  [Male, Male, Male]
# Human-Kree                                                   [Female]
# Icthyo Sapien                                                  [Male]
# Inhuman                                                        [Male]
# Kaiju                                                             [-]
# Kakarantharaian                                                [Male]
# Korugaran                                                      [Male]
# Luphomoid                                                    [Female]
# Martian                                                        [Male]
# Metahuman                                                      [Male]
# Mutant              [Male, Male, Male, Female, Female, Male, Male,...
# New God                                                  [Male, Male]
# Neyaphem                                                       [Male]
# Rodian                                                         [Male]
# Strontian                                                      [Male]
# Talokite                                                     [Female]
# Tamaranean                                                   [Female]
# Ungaran                                                        [Male]
# Xenomorph XX121                                                [Male]
# Yoda's species                                                 [Male]
# Zen-Whoberian                                                [Female]
#
#                                                             Eye color  \
# Race
# -                                                        [black, red]
# Alien                                      [white, white, red, white]
# Android                                  [green, white, -, red, gold]
# Bizarro                                                       [black]
# Bolovaxian                                                      [red]
# Cosmic Entity                                                  [blue]
# Cyborg                                                            [-]
# Czarnian                                                        [red]
# Dathomirian Zabrak                                     [yellow / red]
# Demon                                                      [red, red]
# Eternal                                                         [red]
# Frost Giant                                                   [white]
# God / Eternal                                    [white, red, yellow]
# Gungan                                                       [yellow]
# Human               [green, blue, green, blue, red, green, purple,...
# Human / Altered                                                 [red]
# Human / Cosmic                                         [white, white]
# Human / Radiation                               [blue, green, yellow]
# Human-Kree                                                    [green]
# Icthyo Sapien                                                  [blue]
# Inhuman                                                       [green]
# Kaiju                                                             [-]
# Kakarantharaian                                                 [red]
# Korugaran                                                     [black]
# Luphomoid                                                      [blue]
# Martian                                                         [red]
# Metahuman                                                       [red]
# Mutant              [red, blue, blue, green, red, green, blue, blu...
# New God                                                    [red, red]
# Neyaphem                                                     [yellow]
# Rodian                                                       [purple]
# Strontian                                                      [blue]
# Talokite                                                      [black]
# Tamaranean                                                    [green]
# Ungaran                                                        [blue]
# Xenomorph XX121                                                   [-]
# Yoda's species                                                [brown]
# Zen-Whoberian                                                [yellow]
#
#                                                            Hair color  \
# Race
# -                                                  [No Hair, No Hair]
# Alien                                 [Orange, White, Black, No Hair]
# Android                             [No Hair, No Hair, -, -, No Hair]
# Bizarro                                                       [Black]
# Bolovaxian                                                  [No Hair]
# Cosmic Entity                                               [No Hair]
# Cyborg                                                            [-]
# Czarnian                                                      [Black]
# Dathomirian Zabrak                                                [-]
# Demon                                                [White, No Hair]
# Eternal                                                     [No Hair]
# Frost Giant                                                 [No Hair]
# God / Eternal                               [No Hair, No Hair, Black]
# Gungan                                                            [-]
# Human               [Green, Black, Green, Blond, No Hair, Red, Pur...
# Human / Altered                                             [No Hair]
# Human / Cosmic                                         [No Hair, Red]
# Human / Radiation                              [Silver, Green, Black]
# Human-Kree                                                    [Black]
# Icthyo Sapien                                               [No Hair]
# Inhuman                                                     [No Hair]
# Kaiju                                                             [-]
# Kakarantharaian                                             [No Hair]
# Korugaran                                                     [Black]
# Luphomoid                                                   [No Hair]
# Martian                                                     [No Hair]
# Metahuman                                                   [No Hair]
# Mutant              [Black, Blond, Blue, Magenta, White, No Hair, ...
# New God                                              [No Hair, Black]
# Neyaphem                                                      [Black]
# Rodian                                                            [-]
# Strontian                                                      [Blue]
# Talokite                                                      [Black]
# Tamaranean                                                   [Auburn]
# Ungaran                                                     [No Hair]
# Xenomorph XX121                                             [No Hair]
# Yoda's species                                                [White]
# Zen-Whoberian                                                 [Black]
#
#                                                                Height  \
# Race
# -                                                      [-99.0, 213.0]
# Alien                                    [193.0, 201.0, 191.0, 193.0]
# Android                           [198.0, 213.0, 183.0, 206.0, 191.0]
# Bizarro                                                       [191.0]
# Bolovaxian                                                    [234.0]
# Cosmic Entity                                                 [-99.0]
# Cyborg                                                        [-99.0]
# Czarnian                                                      [229.0]
# Dathomirian Zabrak                                            [170.0]
# Demon                                                  [191.0, 193.0]
# Eternal                                                       [201.0]
# Frost Giant                                                   [304.8]
# God / Eternal                                   [-99.0, -99.0, -99.0]
# Gungan                                                        [193.0]
# Human               [173.0, 173.0, 196.0, -99.0, 188.0, 168.0, 180...
# Human / Altered                                               [193.0]
# Human / Cosmic                                         [-99.0, 163.0]
# Human / Radiation                               [193.0, 244.0, 213.0]
# Human-Kree                                                    [168.0]
# Icthyo Sapien                                                 [191.0]
# Inhuman                                                       [188.0]
# Kaiju                                                         [108.0]
# Kakarantharaian                                               [975.0]
# Korugaran                                                     [201.0]
# Luphomoid                                                     [185.0]
# Martian                                                       [201.0]
# Metahuman                                                     [244.0]
# Mutant              [213.0, 183.0, 180.0, 165.0, 183.0, -99.0, 183...
# New God                                                [267.0, 183.0]
# Neyaphem                                                      [183.0]
# Rodian                                                        [170.0]
# Strontian                                                     [198.0]
# Talokite                                                      [173.0]
# Tamaranean                                                    [193.0]
# Ungaran                                                       [185.0]
# Xenomorph XX121                                               [244.0]
# Yoda's species                                                 [66.0]
# Zen-Whoberian                                                 [183.0]
#
#                                                             Publisher  \
# Race
# -                                                [nan, Marvel Comics]
# Alien               [Marvel Comics, Marvel Comics, Marvel Comics, ...
# Android             [DC Comics, George Lucas, Dark Horse Comics, M...
# Bizarro                                                   [DC Comics]
# Bolovaxian                                                [DC Comics]
# Cosmic Entity                                         [Marvel Comics]
# Cyborg                                            [Dark Horse Comics]
# Czarnian                                                  [DC Comics]
# Dathomirian Zabrak                                     [George Lucas]
# Demon                                      [Marvel Comics, DC Comics]
# Eternal                                               [Marvel Comics]
# Frost Giant                                           [Marvel Comics]
# God / Eternal                       [DC Comics, DC Comics, DC Comics]
# Gungan                                                 [George Lucas]
# Human               [DC Comics, Marvel Comics, DC Comics, DC Comic...
# Human / Altered                                       [Marvel Comics]
# Human / Cosmic                             [DC Comics, Marvel Comics]
# Human / Radiation           [DC Comics, Marvel Comics, Marvel Comics]
# Human-Kree                                            [Marvel Comics]
# Icthyo Sapien                                     [Dark Horse Comics]
# Inhuman                                               [Marvel Comics]
# Kaiju                                                           [nan]
# Kakarantharaian                                       [Marvel Comics]
# Korugaran                                                 [DC Comics]
# Luphomoid                                             [Marvel Comics]
# Martian                                                   [DC Comics]
# Metahuman                                                 [DC Comics]
# Mutant              [Marvel Comics, Marvel Comics, Marvel Comics, ...
# New God                                        [DC Comics, DC Comics]
# Neyaphem                                              [Marvel Comics]
# Rodian                                                 [George Lucas]
# Strontian                                             [Marvel Comics]
# Talokite                                                  [DC Comics]
# Tamaranean                                                [DC Comics]
# Ungaran                                                   [DC Comics]
# Xenomorph XX121                                   [Dark Horse Comics]
# Yoda's species                                         [George Lucas]
# Zen-Whoberian                                         [Marvel Comics]
#
#                                                            Skin color  \
# Race
# -                                                        [red, green]
# Alien                                     [gold, grey, green, silver]
# Android                            [green, gray, silver, silver, red]
# Bizarro                                                       [white]
# Bolovaxian                                                     [pink]
# Cosmic Entity                                                  [gold]
# Cyborg                                                       [silver]
# Czarnian                                                 [blue-white]
# Dathomirian Zabrak                                      [red / black]
# Demon                                                 [white, yellow]
# Eternal                                                      [purple]
# Frost Giant                                                   [white]
# God / Eternal                                     [white, green, red]
# Gungan                                               [orange / white]
# Human               [green, white, white, blue, red, green, purple...
# Human / Altered                                               [green]
# Human / Cosmic                                           [blue, gold]
# Human / Radiation                                [silver, green, red]
# Human-Kree                                                    [green]
# Icthyo Sapien                                                  [blue]
# Inhuman                                                       [green]
# Kaiju                                                          [grey]
# Kakarantharaian                                               [green]
# Korugaran                                                       [red]
# Luphomoid                                                      [blue]
# Martian                                                       [green]
# Metahuman                                                     [green]
# Mutant              [grey, blue, blue, pink, blue, green, red, gre...
# New God                                                 [grey, white]
# Neyaphem                                                        [red]
# Rodian                                                        [green]
# Strontian                                                    [purple]
# Talokite                                                       [blue]
# Tamaranean                                                   [orange]
# Ungaran                                                         [red]
# Xenomorph XX121                                               [black]
# Yoda's species                                                [green]
# Zen-Whoberian                                                 [green]
#
#                                                             Alignment  \
# Race
# -                                                        [good, good]
# Alien                                         [good, good, bad, good]
# Android                                   [bad, good, bad, bad, good]
# Bizarro                                                     [neutral]
# Bolovaxian                                                     [good]
# Cosmic Entity                                               [neutral]
# Cyborg                                                          [bad]
# Czarnian                                                    [neutral]
# Dathomirian Zabrak                                              [bad]
# Demon                                                  [bad, neutral]
# Eternal                                                         [bad]
# Frost Giant                                                    [good]
# God / Eternal                                        [good, bad, bad]
# Gungan                                                         [good]
# Human                      [good, good, bad, bad, bad, bad, bad, bad]
# Human / Altered                                                [good]
# Human / Cosmic                                           [good, good]
# Human / Radiation                               [good, good, neutral]
# Human-Kree                                                     [good]
# Icthyo Sapien                                                  [good]
# Inhuman                                                        [good]
# Kaiju                                                           [bad]
# Kakarantharaian                                                [good]
# Korugaran                                                   [neutral]
# Luphomoid                                                       [bad]
# Martian                                                        [good]
# Metahuman                                                       [bad]
# Mutant              [bad, good, good, good, neutral, good, bad, go...
# New God                                                    [bad, bad]
# Neyaphem                                                        [bad]
# Rodian                                                          [bad]
# Strontian                                                   [neutral]
# Talokite                                                       [good]
# Tamaranean                                                     [good]
# Ungaran                                                        [good]
# Xenomorph XX121                                                 [bad]
# Yoda's species                                                 [good]
# Zen-Whoberian                                                  [good]
#
#                                                                Weight  \
# Race
# -                                                      [-99.0, 225.0]
# Alien                                      [98.0, 97.0, 106.0, 101.0]
# Android                           [135.0, -99.0, 146.0, 331.0, 135.0]
# Bizarro                                                       [155.0]
# Bolovaxian                                                    [324.0]
# Cosmic Entity                                                 [-99.0]
# Cyborg                                                        [149.0]
# Czarnian                                                      [288.0]
# Dathomirian Zabrak                                            [-99.0]
# Demon                                                  [104.0, 203.0]
# Eternal                                                       [443.0]
# Frost Giant                                                   [-99.0]
# God / Eternal                                   [-99.0, -99.0, -99.0]
# Gungan                                                        [-99.0]
# Human               [68.0, 54.0, 86.0, -99.0, 97.0, 50.0, 74.0, 20...
# Human / Altered                                               [306.0]
# Human / Cosmic                                          [-99.0, 59.0]
# Human / Radiation                                [90.0, 630.0, 630.0]
# Human-Kree                                                     [52.0]
# Icthyo Sapien                                                  [65.0]
# Inhuman                                                        [86.0]
# Kaiju                                                           [nan]
# Kakarantharaian                                                [18.0]
# Korugaran                                                      [92.0]
# Luphomoid                                                      [83.0]
# Martian                                                       [135.0]
# Metahuman                                                     [356.0]
# Mutant              [135.0, 68.0, 181.0, 56.0, 67.0, -99.0, 88.0, ...
# New God                                                 [817.0, 91.0]
# Neyaphem                                                       [67.0]
# Rodian                                                        [-99.0]
# Strontian                                                     [268.0]
# Talokite                                                       [54.0]
# Tamaranean                                                     [71.0]
# Ungaran                                                        [90.0]
# Xenomorph XX121                                               [169.0]
# Yoda's species                                                 [17.0]
# Zen-Whoberian                                                  [77.0]
#
#                                                              Tallness
# Race
# -                                                    [Not tall, Tall]
# Alien                            [Not tall, Tall, Not tall, Not tall]
# Android                    [Not tall, Tall, Not tall, Tall, Not tall]
# Bizarro                                                    [Not tall]
# Bolovaxian                                                     [Tall]
# Cosmic Entity                                              [Not tall]
# Cyborg                                                     [Not tall]
# Czarnian                                                       [Tall]
# Dathomirian Zabrak                                         [Not tall]
# Demon                                            [Not tall, Not tall]
# Eternal                                                        [Tall]
# Frost Giant                                                    [Tall]
# God / Eternal                          [Not tall, Not tall, Not tall]
# Gungan                                                     [Not tall]
# Human               [Not tall, Not tall, Not tall, Not tall, Not t...
# Human / Altered                                            [Not tall]
# Human / Cosmic                                   [Not tall, Not tall]
# Human / Radiation                              [Not tall, Tall, Tall]
# Human-Kree                                                 [Not tall]
# Icthyo Sapien                                              [Not tall]
# Inhuman                                                    [Not tall]
# Kaiju                                                      [Not tall]
# Kakarantharaian                                                [Tall]
# Korugaran                                                      [Tall]
# Luphomoid                                                  [Not tall]
# Martian                                                        [Tall]
# Metahuman                                                      [Tall]
# Mutant              [Tall, Not tall, Not tall, Not tall, Not tall,...
# New God                                              [Tall, Not tall]
# Neyaphem                                                   [Not tall]
# Rodian                                                     [Not tall]
# Strontian                                                  [Not tall]
# Talokite                                                   [Not tall]
# Tamaranean                                                 [Not tall]
# Ungaran                                                    [Not tall]
# Xenomorph XX121                                                [Tall]
# Yoda's species                                             [Not tall]
# Zen-Whoberian                                              [Not tall]

# %%
(df['Alignment'] == 'good').mean() * 100
# Out:
# 48.61111111111111

# %%
(df['Alignment'] == 'good').sum() / (df['Alignment'] == 'good').size
# Out:
# 0.4861111111111111

# %%
df.groupby("Race")['Alignment'].apply(len)
# Out:
# Race
# -                      2
# Alien                  4
# Android                5
# Bizarro                1
# Bolovaxian             1
# Cosmic Entity          1
# Cyborg                 1
# Czarnian               1
# Dathomirian Zabrak     1
# Demon                  2
# Eternal                1
# Frost Giant            1
# God / Eternal          3
# Gungan                 1
# Human                  8
# Human / Altered        1
# Human / Cosmic         2
# Human / Radiation      3
# Human-Kree             1
# Icthyo Sapien          1
# Inhuman                1
# Kaiju                  1
# Kakarantharaian        1
# Korugaran              1
# Luphomoid              1
# Martian                1
# Metahuman              1
# Mutant                13
# New God                2
# Neyaphem               1
# Rodian                 1
# Strontian              1
# Talokite               1
# Tamaranean             1
# Ungaran                1
# Xenomorph XX121        1
# Yoda's species         1
# Zen-Whoberian          1
# Name: Alignment, dtype: int64

# %%
def perc_good(grouping):
    """Devuelve el porcentaje que son 'good'."""
    return (grouping == 'good').mean() * 100.0


df.groupby("Race").agg(
    {
        'name': 'count',
        'Height': ['mean', 'std'],
        'Weight': ['mean', 'std'],
        'Alignment': perc_good,
    }
).head(20)
# Out:
#                     name      Height               Weight              \
#                    count        mean         std     mean         std
# Race
# -                      2   57.000000  220.617316   63.000  229.102597
# Alien                  4  194.500000    4.434712  100.500    4.041452
# Android                5  198.200000   11.861703  129.600  152.600131
# Bizarro                1  191.000000         NaN  155.000         NaN
# Bolovaxian             1  234.000000         NaN  324.000         NaN
# Cosmic Entity          1  -99.000000         NaN  -99.000         NaN
# Cyborg                 1  -99.000000         NaN  149.000         NaN
# Czarnian               1  229.000000         NaN  288.000         NaN
# Dathomirian Zabrak     1  170.000000         NaN  -99.000         NaN
# Demon                  2  192.000000    1.414214  153.500   70.003571
# Eternal                1  201.000000         NaN  443.000         NaN
# Frost Giant            1  304.800000         NaN  -99.000         NaN
# God / Eternal          3  -99.000000    0.000000  -99.000    0.000000
# Gungan                 1  193.000000         NaN  -99.000         NaN
# Human                  8  145.500000   99.215494   66.625   82.652349
# Human / Altered        1  193.000000         NaN  306.000         NaN
# Human / Cosmic         2   32.000000  185.261977  -20.000  111.722871
# Human / Radiation      3  216.666667   25.696952  450.000  311.769145
# Human-Kree             1  168.000000         NaN   52.000         NaN
# Icthyo Sapien          1  191.000000         NaN   65.000         NaN
#
#                      Alignment
#                      perc_good
# Race
# -                   100.000000
# Alien                75.000000
# Android              40.000000
# Bizarro               0.000000
# Bolovaxian          100.000000
# Cosmic Entity         0.000000
# Cyborg                0.000000
# Czarnian              0.000000
# Dathomirian Zabrak    0.000000
# Demon                 0.000000
# Eternal               0.000000
# Frost Giant         100.000000
# God / Eternal        33.333333
# Gungan              100.000000
# Human                25.000000
# Human / Altered     100.000000
# Human / Cosmic      100.000000
# Human / Radiation    66.666667
# Human-Kree          100.000000
# Icthyo Sapien       100.000000

# %% [markdown]
# Algunas agregaciones tienen métodos para realizarlos directamente

# %%
df.Race.value_counts()
# Out:
# Mutant                13
# Human                  8
# Android                5
# Alien                  4
# Human / Radiation      3
# God / Eternal          3
# Human / Cosmic         2
# -                      2
# New God                2
# Demon                  2
# Strontian              1
# Metahuman              1
# Human / Altered        1
# Yoda's species         1
# Czarnian               1
# Frost Giant            1
# Gungan                 1
# Talokite               1
# Korugaran              1
# Cyborg                 1
# Neyaphem               1
# Cosmic Entity          1
# Rodian                 1
# Bizarro                1
# Bolovaxian             1
# Human-Kree             1
# Tamaranean             1
# Luphomoid              1
# Dathomirian Zabrak     1
# Eternal                1
# Martian                1
# Kakarantharaian        1
# Xenomorph XX121        1
# Zen-Whoberian          1
# Inhuman                1
# Icthyo Sapien          1
# Kaiju                  1
# Ungaran                1
# Name: Race, dtype: int64

# %% [markdown]
# Y si lo queremos como porcentajes?

# %%
df.Race.value_counts() / df.Race.value_counts().sum() * 100
# Out:
# Mutant                18.055556
# Human                 11.111111
# Android                6.944444
# Alien                  5.555556
# Human / Radiation      4.166667
# God / Eternal          4.166667
# Human / Cosmic         2.777778
# -                      2.777778
# New God                2.777778
# Demon                  2.777778
# Strontian              1.388889
# Metahuman              1.388889
# Human / Altered        1.388889
# Yoda's species         1.388889
# Czarnian               1.388889
# Frost Giant            1.388889
# Gungan                 1.388889
# Talokite               1.388889
# Korugaran              1.388889
# Cyborg                 1.388889
# Neyaphem               1.388889
# Cosmic Entity          1.388889
# Rodian                 1.388889
# Bizarro                1.388889
# Bolovaxian             1.388889
# Human-Kree             1.388889
# Tamaranean             1.388889
# Luphomoid              1.388889
# Dathomirian Zabrak     1.388889
# Eternal                1.388889
# Martian                1.388889
# Kakarantharaian        1.388889
# Xenomorph XX121        1.388889
# Zen-Whoberian          1.388889
# Inhuman                1.388889
# Icthyo Sapien          1.388889
# Kaiju                  1.388889
# Ungaran                1.388889
# Name: Race, dtype: float64

# %%
df.Race.value_counts(normalize=True)
# Out:
# Mutant                0.180556
# Human                 0.111111
# Android               0.069444
# Alien                 0.055556
# Human / Radiation     0.041667
# God / Eternal         0.041667
# Human / Cosmic        0.027778
# -                     0.027778
# New God               0.027778
# Demon                 0.027778
# Strontian             0.013889
# Metahuman             0.013889
# Human / Altered       0.013889
# Yoda's species        0.013889
# Czarnian              0.013889
# Frost Giant           0.013889
# Gungan                0.013889
# Talokite              0.013889
# Korugaran             0.013889
# Cyborg                0.013889
# Neyaphem              0.013889
# Cosmic Entity         0.013889
# Rodian                0.013889
# Bizarro               0.013889
# Bolovaxian            0.013889
# Human-Kree            0.013889
# Tamaranean            0.013889
# Luphomoid             0.013889
# Dathomirian Zabrak    0.013889
# Eternal               0.013889
# Martian               0.013889
# Kakarantharaian       0.013889
# Xenomorph XX121       0.013889
# Zen-Whoberian         0.013889
# Inhuman               0.013889
# Icthyo Sapien         0.013889
# Kaiju                 0.013889
# Ungaran               0.013889
# Name: Race, dtype: float64

# %% [markdown]
# Veamos como podemos obtener las filas del dataframe original donde la columna `Race` este entre aquellos valores con mas del 5% de repeticiones.

# %%
over5 = df.Race.value_counts(normalize=True) > 0.05
mutants_over5 = df.Race.value_counts()[over5]

# %% [markdown]
# Teniendo la indexacion, veamos como resolverlo con `isin`

# %%
df[df.Race.isin(mutants_over5.index)].head(5)
# Out:
#          name  Gender Eye color    Race Hair color  Height      Publisher  \
# 3  Apocalypse    Male       red  Mutant      Black   213.0  Marvel Comics
# 4   Archangel    Male      blue  Mutant      Blond   183.0  Marvel Comics
# 5      Ardina  Female     white   Alien     Orange   193.0  Marvel Comics
# 7       Beast    Male      blue  Mutant       Blue   180.0  Marvel Comics
# 8   Beast Boy    Male     green   Human      Green   173.0      DC Comics
#
#   Skin color Alignment  Weight  Tallness
# 3       grey       bad   135.0      Tall
# 4       blue      good    68.0  Not tall
# 5       gold      good    98.0  Not tall
# 7       blue      good   181.0  Not tall
# 8      green      good    68.0  Not tall

# %% [markdown]
# Alternativamente, con `merge`

# %%
df.merge(mutants_over5, left_on='Race', right_index=True, how='inner')
# Out:
#        Race           name  Gender                Eye color   Race_x  \
# 3    Mutant     Apocalypse    Male                      red   Mutant
# 4    Mutant      Archangel    Male                     blue   Mutant
# 7    Mutant          Beast    Male                     blue   Mutant
# 11   Mutant          Blink  Female                    green   Mutant
# 15   Mutant        Copycat  Female                      red   Mutant
# 19   Mutant      Donatello    Male                    green   Mutant
# 24   Mutant         Exodus    Male                     blue   Mutant
# 39   Mutant       Leonardo    Male                     blue   Mutant
# 45   Mutant   Michelangelo    Male                     blue   Mutant
# 46   Mutant       Mystique  Female  yellow (without irises)   Mutant
# 51   Mutant        Raphael    Male                        -   Mutant
# 60   Mutant          Swarm    Male                   yellow   Mutant
# 65   Mutant           Toad    Male                    black   Mutant
# 5     Alien         Ardina  Female                    white    Alien
# 14    Alien        Century    Male                    white    Alien
# 23    Alien       Evilhawk    Male                      red    Alien
# 54    Alien  Silver Surfer    Male                    white    Alien
# 8     Human      Beast Boy    Male                    green    Human
# 18    Human         Domino  Female                     blue    Human
# 32    Human          Joker    Male                    green    Human
# 35    Human   Killer Frost  Female                     blue    Human
# 37    Human           Klaw    Male                      red    Human
# 49    Human     Poison Ivy  Female                    green    Human
# 50    Human     Purple Man    Male                   purple    Human
# 64    Human    Tiger Shark    Male                     grey    Human
# 12  Android       Brainiac    Male                    green  Android
# 33  Android          K-2SO    Male                    white  Android
# 61  Android         T-1000    Male                        -  Android
# 68  Android         Ultron    Male                      red  Android
# 69  Android         Vision    Male                     gold  Android
#
#       Hair color  Height          Publisher Skin color Alignment  Weight  \
# 3          Black   213.0      Marvel Comics       grey       bad   135.0
# 4          Blond   183.0      Marvel Comics       blue      good    68.0
# 7           Blue   180.0      Marvel Comics       blue      good   181.0
# 11       Magenta   165.0      Marvel Comics       pink      good    56.0
# 15         White   183.0      Marvel Comics       blue   neutral    67.0
# 19       No Hair   -99.0     IDW Publishing      green      good   -99.0
# 24         Black   183.0      Marvel Comics        red       bad    88.0
# 39       No Hair   -99.0     IDW Publishing      green      good   -99.0
# 45             -   -99.0     IDW Publishing      green      good   -99.0
# 46  Red / Orange   178.0      Marvel Comics       blue       bad    54.0
# 51       No Hair   -99.0     IDW Publishing      green      good   -99.0
# 60       No Hair   196.0      Marvel Comics     yellow       bad    47.0
# 65         Brown   175.0      Marvel Comics      green   neutral    76.0
# 5         Orange   193.0      Marvel Comics       gold      good    98.0
# 14         White   201.0      Marvel Comics       grey      good    97.0
# 23         Black   191.0      Marvel Comics      green       bad   106.0
# 54       No Hair   193.0      Marvel Comics     silver      good   101.0
# 8          Green   173.0          DC Comics      green      good    68.0
# 18         Black   173.0      Marvel Comics      white      good    54.0
# 32         Green   196.0          DC Comics      white       bad    86.0
# 35         Blond   -99.0          DC Comics       blue       bad   -99.0
# 37       No Hair   188.0      Marvel Comics        red       bad    97.0
# 49           Red   168.0          DC Comics      green       bad    50.0
# 50        Purple   180.0      Marvel Comics     purple       bad    74.0
# 64       No Hair   185.0      Marvel Comics       grey       bad   203.0
# 12       No Hair   198.0          DC Comics      green       bad   135.0
# 33       No Hair   213.0       George Lucas       gray      good   -99.0
# 61             -   183.0  Dark Horse Comics     silver       bad   146.0
# 68             -   206.0      Marvel Comics     silver       bad   331.0
# 69       No Hair   191.0      Marvel Comics        red      good   135.0
#
#     Tallness  Race_y
# 3       Tall      13
# 4   Not tall      13
# 7   Not tall      13
# 11  Not tall      13
# 15  Not tall      13
# 19  Not tall      13
# 24  Not tall      13
# 39  Not tall      13
# 45  Not tall      13
# 46  Not tall      13
# 51  Not tall      13
# 60  Not tall      13
# 65  Not tall      13
# 5   Not tall       4
# 14      Tall       4
# 23  Not tall       4
# 54  Not tall       4
# 8   Not tall       8
# 18  Not tall       8
# 32  Not tall       8
# 35  Not tall       8
# 37  Not tall       8
# 49  Not tall       8
# 50  Not tall       8
# 64  Not tall       8
# 12  Not tall       5
# 33      Tall       5
# 61  Not tall       5
# 68      Tall       5
# 69  Not tall       5

# %% [markdown]
# ## Pivoting

# %%
pd.pivot_table(
    df,
    index='Race',
    columns=['Gender'],
    values=['Height', 'Weight', 'Alignment'],
    aggfunc={
        'Height': 'mean',
        'Weight': 'mean',
        'Alignment': lambda x: Counter(x).most_common(1)[0][0],
    },
)
# Out:
#                    Alignment                 Height                          \
# Gender                     - Female     Male      -      Female        Male
# Race
# -                        NaN    NaN     good    NaN         NaN   57.000000
# Alien                    NaN   good     good    NaN  193.000000  195.000000
# Android                  NaN    NaN      bad    NaN         NaN  198.200000
# Bizarro                  NaN    NaN  neutral    NaN         NaN  191.000000
# Bolovaxian               NaN    NaN     good    NaN         NaN  234.000000
# Cosmic Entity        neutral    NaN      NaN  -99.0         NaN         NaN
# Cyborg                   NaN    bad      NaN    NaN  -99.000000         NaN
# Czarnian                 NaN    NaN  neutral    NaN         NaN  229.000000
# Dathomirian Zabrak       NaN    NaN      bad    NaN         NaN  170.000000
# Demon                    NaN    NaN      bad    NaN         NaN  192.000000
# Eternal                  NaN    NaN      bad    NaN         NaN  201.000000
# Frost Giant              NaN    NaN     good    NaN         NaN  304.800000
# God / Eternal            NaN    NaN      bad    NaN         NaN  -99.000000
# Gungan                   NaN    NaN     good    NaN         NaN  193.000000
# Human                    NaN    bad      bad    NaN   80.666667  184.400000
# Human / Altered          NaN    NaN     good    NaN         NaN  193.000000
# Human / Cosmic           NaN   good     good    NaN  163.000000  -99.000000
# Human / Radiation        NaN    NaN     good    NaN         NaN  216.666667
# Human-Kree               NaN   good      NaN    NaN  168.000000         NaN
# Icthyo Sapien            NaN    NaN     good    NaN         NaN  191.000000
# Inhuman                  NaN    NaN     good    NaN         NaN  188.000000
# Kaiju                    bad    NaN      NaN  108.0         NaN         NaN
# Kakarantharaian          NaN    NaN     good    NaN         NaN  975.000000
# Korugaran                NaN    NaN  neutral    NaN         NaN  201.000000
# Luphomoid                NaN    bad      NaN    NaN  185.000000         NaN
# Martian                  NaN    NaN     good    NaN         NaN  201.000000
# Metahuman                NaN    NaN      bad    NaN         NaN  244.000000
# Mutant                   NaN   good     good    NaN  175.333333   73.400000
# New God                  NaN    NaN      bad    NaN         NaN  225.000000
# Neyaphem                 NaN    NaN      bad    NaN         NaN  183.000000
# Rodian                   NaN    NaN      bad    NaN         NaN  170.000000
# Strontian                NaN    NaN  neutral    NaN         NaN  198.000000
# Talokite                 NaN   good      NaN    NaN  173.000000         NaN
# Tamaranean               NaN   good      NaN    NaN  193.000000         NaN
# Ungaran                  NaN    NaN     good    NaN         NaN  185.000000
# Xenomorph XX121          NaN    NaN      bad    NaN         NaN  244.000000
# Yoda's species           NaN    NaN     good    NaN         NaN   66.000000
# Zen-Whoberian            NaN   good      NaN    NaN  183.000000         NaN
#
#                    Weight
# Gender                  -      Female        Male
# Race
# -                     NaN         NaN   63.000000
# Alien                 NaN   98.000000  101.333333
# Android               NaN         NaN  129.600000
# Bizarro               NaN         NaN  155.000000
# Bolovaxian            NaN         NaN  324.000000
# Cosmic Entity       -99.0         NaN         NaN
# Cyborg                NaN  149.000000         NaN
# Czarnian              NaN         NaN  288.000000
# Dathomirian Zabrak    NaN         NaN  -99.000000
# Demon                 NaN         NaN  153.500000
# Eternal               NaN         NaN  443.000000
# Frost Giant           NaN         NaN  -99.000000
# God / Eternal         NaN         NaN  -99.000000
# Gungan                NaN         NaN  -99.000000
# Human                 NaN    1.666667  105.600000
# Human / Altered       NaN         NaN  306.000000
# Human / Cosmic        NaN   59.000000  -99.000000
# Human / Radiation     NaN         NaN  450.000000
# Human-Kree            NaN   52.000000         NaN
# Icthyo Sapien         NaN         NaN   65.000000
# Inhuman               NaN         NaN   86.000000
# Kaiju                 NaN         NaN         NaN
# Kakarantharaian       NaN         NaN   18.000000
# Korugaran             NaN         NaN   92.000000
# Luphomoid             NaN   83.000000         NaN
# Martian               NaN         NaN  135.000000
# Metahuman             NaN         NaN  356.000000
# Mutant                NaN   59.000000   19.900000
# New God               NaN         NaN  454.000000
# Neyaphem              NaN         NaN   67.000000
# Rodian                NaN         NaN  -99.000000
# Strontian             NaN         NaN  268.000000
# Talokite              NaN   54.000000         NaN
# Tamaranean            NaN   71.000000         NaN
# Ungaran               NaN         NaN   90.000000
# Xenomorph XX121       NaN         NaN  169.000000
# Yoda's species        NaN         NaN   17.000000
# Zen-Whoberian         NaN   77.000000         NaN

# %% [markdown]
# # Checkpoint
#
# Desde el siguiente snippet:
# ```python
# import pandas as pd
#
# pd.read_csv("https://docs.google.com/spreadsheets/d/1nuJAaaH_IP8Q80CsyS940EVaePkbmqhN3vlorDxYMnA/export?format=csv")
# ```
#
# Encontrar el promedio de altura por raza, considerando solo los personajes _buenos_.

# %% [markdown]
# # Sobre vistas y columnas

# %%
df_marvel = df[df.Publisher == 'Marvel Comics']

# %%
def alignment_to_numeric(alignment):
    return {'bad': -1, 'good': 1, 'neutral': 0}[alignment]


df_marvel['numeric_alineation'] = df_marvel.Alignment.apply(alignment_to_numeric)
# Out:
# /opt/hostedtoolcache/Python/3.7.11/x64/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df_marvel = df[df.Publisher == 'Marvel Comics'].copy()

# %%
df_marvel.loc[:, 'numeric_alineation'] = df_marvel.Alignment.apply(alignment_to_numeric)

# %%
df_marvel.head()
# Out:
#          name  Gender Eye color      Race Hair color  Height      Publisher  \
# 3  Apocalypse    Male       red    Mutant      Black   213.0  Marvel Comics
# 4   Archangel    Male      blue    Mutant      Blond   183.0  Marvel Comics
# 5      Ardina  Female     white     Alien     Orange   193.0  Marvel Comics
# 6      Azazel    Male    yellow  Neyaphem      Black   183.0  Marvel Comics
# 7       Beast    Male      blue    Mutant       Blue   180.0  Marvel Comics
#
#   Skin color Alignment  Weight  Tallness  numeric_alineation
# 3       grey       bad   135.0      Tall                  -1
# 4       blue      good    68.0  Not tall                   1
# 5       gold      good    98.0  Not tall                   1
# 6        red       bad    67.0  Not tall                  -1
# 7       blue      good   181.0  Not tall                   1

# %%
df_marvel.numeric_alineation.mean()
# Out:
# 0.11428571428571428

# %% [markdown]
# Una excelente guía al respecto: [link](https://www.dataquest.io/blog/settingwithcopywarning/)

# %% [markdown]
# # Ordenando

# %%
df.set_index('name').sort_index()
# Out:
#            Gender Eye color             Race Hair color  Height  \
# name
# Abe Sapien   Male      blue    Icthyo Sapien    No Hair   191.0
# Abin Sur     Male      blue          Ungaran    No Hair   185.0
# Alien        Male         -  Xenomorph XX121    No Hair   244.0
# Apocalypse   Male       red           Mutant      Black   213.0
# Archangel    Male      blue           Mutant      Blond   183.0
# ...           ...       ...              ...        ...     ...
# Triton       Male     green          Inhuman    No Hair   188.0
# Ultron       Male       red          Android          -   206.0
# Vision       Male      gold          Android    No Hair   191.0
# Ymir         Male     white      Frost Giant    No Hair   304.8
# Yoda         Male     brown   Yoda's species      White    66.0
#
#                     Publisher Skin color Alignment  Weight  Tallness
# name
# Abe Sapien  Dark Horse Comics       blue      good    65.0  Not tall
# Abin Sur            DC Comics        red      good    90.0  Not tall
# Alien       Dark Horse Comics      black       bad   169.0      Tall
# Apocalypse      Marvel Comics       grey       bad   135.0      Tall
# Archangel       Marvel Comics       blue      good    68.0  Not tall
# ...                       ...        ...       ...     ...       ...
# Triton          Marvel Comics      green      good    86.0  Not tall
# Ultron          Marvel Comics     silver       bad   331.0      Tall
# Vision          Marvel Comics        red      good   135.0  Not tall
# Ymir            Marvel Comics      white      good   -99.0      Tall
# Yoda             George Lucas      green      good    17.0  Not tall
#
# [72 rows x 10 columns]

# %%
df.sort_values(by=['Height', 'Weight'], ascending=False)
# Out:
#              name Gender Eye color               Race Hair color  Height  \
# 25  Fin Fang Foom   Male       red    Kakarantharaian    No Hair   975.0
# 70           Ymir   Male     white        Frost Giant    No Hair   304.8
# 16       Darkseid   Male       red            New God    No Hair   267.0
# 30           Hulk   Male     green  Human / Radiation      Green   244.0
# 34    Killer Croc   Male       red          Metahuman    No Hair   244.0
# ..            ...    ...       ...                ...        ...     ...
# 45   Michelangelo   Male      blue             Mutant          -   -99.0
# 51        Raphael   Male         -             Mutant    No Hair   -99.0
# 56        Spectre   Male     white      God / Eternal    No Hair   -99.0
# 59    Swamp Thing   Male       red      God / Eternal    No Hair   -99.0
# 66         Trigon   Male    yellow      God / Eternal      Black   -99.0
#
#          Publisher Skin color Alignment  Weight  Tallness
# 25   Marvel Comics      green      good    18.0      Tall
# 70   Marvel Comics      white      good   -99.0      Tall
# 16       DC Comics       grey       bad   817.0      Tall
# 30   Marvel Comics      green      good   630.0      Tall
# 34       DC Comics      green       bad   356.0      Tall
# ..             ...        ...       ...     ...       ...
# 45  IDW Publishing      green      good   -99.0  Not tall
# 51  IDW Publishing      green      good   -99.0  Not tall
# 56       DC Comics      white      good   -99.0  Not tall
# 59       DC Comics      green       bad   -99.0  Not tall
# 66       DC Comics        red       bad   -99.0  Not tall
#
# [72 rows x 11 columns]

# %% [markdown]
# # Operaciones de strings

# %%
df.name.apply(lambda x: x.lower())
# Out:
# 0     abe sapien
# 1       abin sur
# 2          alien
# 3     apocalypse
# 4      archangel
#          ...
# 67        triton
# 68        ultron
# 69        vision
# 70          ymir
# 71          yoda
# Name: name, Length: 72, dtype: object

# %% [markdown]
# Entre [otras](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html)

# %% [markdown]
# # Manejo de fechas

# %% [markdown]
# ### Timestamp

# %%
pd.Timestamp("2020-04-14 04:32:18 PM")
# Out:
# Timestamp('2020-04-14 16:32:18')

# %% [markdown]
# ### DatetimeIndex

# %%
fechas = ['2021-03-21', '2021-09-21', '2021/12/21']
indice_fechas = pd.DatetimeIndex(fechas)
indice_fechas
# Out:
# DatetimeIndex(['2021-03-21', '2021-09-21', '2021-12-21'], dtype='datetime64[ns]', freq=None)

# %%
descripciones = ['otoño', 'primavera', 'verano']
desc_serie = pd.Series(data=descripciones, index=indice_fechas)
desc_serie
# Out:
# 2021-03-21        otoño
# 2021-09-21    primavera
# 2021-12-21       verano
# dtype: object

# %% [markdown]
# ### to_datetime

# %%
pd.to_datetime('2020/03/30 17:43:09')
# Out:
# Timestamp('2020-03-30 17:43:09')

# %%
pd.to_datetime(fechas)
# Out:
# DatetimeIndex(['2021-03-21', '2021-09-21', '2021-12-21'], dtype='datetime64[ns]', freq=None)

# %%
serie_fechas = pd.Series(
    ['September 22nd, 2019', '22, 09, 2020', 'Una fecha', 'Oct 15th, 2020']
)
pd.to_datetime(serie_fechas, errors='coerce')
# Out:
# 0   2019-09-22
# 1   2020-09-22
# 2          NaT
# 3   2020-10-15
# dtype: datetime64[ns]

# %% [markdown]
# ### Rangos

# %%
rango_de_tiempo = pd.date_range(start='25/06/2019', end='25/06/2020', freq='D')
rango_de_tiempo
# Out:
# DatetimeIndex(['2019-06-25', '2019-06-26', '2019-06-27', '2019-06-28',
#                '2019-06-29', '2019-06-30', '2019-07-01', '2019-07-02',
#                '2019-07-03', '2019-07-04',
#                ...
#                '2020-06-16', '2020-06-17', '2020-06-18', '2020-06-19',
#                '2020-06-20', '2020-06-21', '2020-06-22', '2020-06-23',
#                '2020-06-24', '2020-06-25'],
#               dtype='datetime64[ns]', length=367, freq='D')

# %%
rango_de_tiempo = pd.date_range(start='25/06/2019', end='25/06/2022', freq='A')
rango_de_tiempo
# Out:
# DatetimeIndex(['2019-12-31', '2020-12-31', '2021-12-31'], dtype='datetime64[ns]', freq='A-DEC')

# %%
desc_serie
# Out:
# 2021-03-21        otoño
# 2021-09-21    primavera
# 2021-12-21       verano
# dtype: object

# %% [markdown]
# ### Filtro por fecha
#
# Usamos un dataset que registra el clima y demás datos para distintas fechas de [alquiler de bicicletas](https://www.kaggle.com/c/bike-sharing-demand/data?select=train.csv).
#
# `pd.read_csv` nos deja leer archivos csv desde una URL. Este dataset esta tambien disponible en el drive de la materia. Leemos el dataset sin bajarlo a un archivo intermedio.

# %%
GSPREADHSEET_DOWNLOAD_URL = (
    "https://docs.google.com/spreadsheets/d/{gid}/export?format=csv&id={gid}".format
)

bicis_df = pd.read_csv(
    GSPREADHSEET_DOWNLOAD_URL(gid="1YocUXbrd6uYpOLpU53uMS-AD9To8y_r30KbZdsSSiVQ")
).set_index('datetime')
bicis_df
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 0:00:00        1        0           0        1   9.84  14.395
# 2011-01-01 1:00:00        1        0           0        1   9.02  13.635
# 2011-01-01 2:00:00        1        0           0        1   9.02  13.635
# 2011-01-01 3:00:00        1        0           0        1   9.84  14.395
# 2011-01-01 4:00:00        1        0           0        1   9.84  14.395
# ...                     ...      ...         ...      ...    ...     ...
# 2012-12-19 19:00:00       4        0           1        1  15.58  19.695
# 2012-12-19 20:00:00       4        0           1        1  14.76  17.425
# 2012-12-19 21:00:00       4        0           1        1  13.94  15.910
# 2012-12-19 22:00:00       4        0           1        1  13.94  17.425
# 2012-12-19 23:00:00       4        0           1        1  13.12  16.665
#
#                      humidity  windspeed  casual  registered  count
# datetime
# 2011-01-01 0:00:00         81     0.0000       3          13     16
# 2011-01-01 1:00:00         80     0.0000       8          32     40
# 2011-01-01 2:00:00         80     0.0000       5          27     32
# 2011-01-01 3:00:00         75     0.0000       3          10     13
# 2011-01-01 4:00:00         75     0.0000       0           1      1
# ...                       ...        ...     ...         ...    ...
# 2012-12-19 19:00:00        50    26.0027       7         329    336
# 2012-12-19 20:00:00        57    15.0013      10         231    241
# 2012-12-19 21:00:00        61    15.0013       4         164    168
# 2012-12-19 22:00:00        61     6.0032      12         117    129
# 2012-12-19 23:00:00        66     8.9981       4          84     88
#
# [10886 rows x 11 columns]

# %%
bicis_df.loc['2012-12-19 20:00:00']
# Out:
# season          4.0000
# holiday         0.0000
# workingday      1.0000
# weather         1.0000
# temp           14.7600
# atemp          17.4250
# humidity       57.0000
# windspeed      15.0013
# casual         10.0000
# registered    231.0000
# count         241.0000
# Name: 2012-12-19 20:00:00, dtype: float64

# %%
# Para poder quedarnos con un rango de fechas, debemos tener el índice ordenado
bicis_df = bicis_df.sort_index()
bicis_df.loc['2012-11-19 20:00:00':'2012-12-30 20:00:00']
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2012-11-19 20:00:00       4        0           1        2  15.58  19.695
# 2012-11-19 21:00:00       4        0           1        2  15.58  19.695
# 2012-11-19 22:00:00       4        0           1        1  13.94  17.425
# 2012-11-19 23:00:00       4        0           1        1  13.94  17.425
# 2012-11-19 2:00:00        4        0           1        2  14.76  16.665
# ...                     ...      ...         ...      ...    ...     ...
# 2012-12-19 5:00:00        4        0           1        1  10.66  14.395
# 2012-12-19 6:00:00        4        0           1        1   9.84  12.880
# 2012-12-19 7:00:00        4        0           1        1  10.66  13.635
# 2012-12-19 8:00:00        4        0           1        1   9.84  12.880
# 2012-12-19 9:00:00        4        0           1        1  11.48  14.395
#
#                      humidity  windspeed  casual  registered  count
# datetime
# 2012-11-19 20:00:00        62    16.9979       7         252    259
# 2012-11-19 21:00:00        54    15.0013      15         188    203
# 2012-11-19 22:00:00        66     7.0015       7         106    113
# 2012-11-19 23:00:00        66     7.0015       2          72     74
# 2012-11-19 2:00:00         66    16.9979       0           5      5
# ...                       ...        ...     ...         ...    ...
# 2012-12-19 5:00:00         75     6.0032       2          29     31
# 2012-12-19 6:00:00         75     6.0032       3         109    112
# 2012-12-19 7:00:00         75     8.9981       3         360    363
# 2012-12-19 8:00:00         87     7.0015      13         665    678
# 2012-12-19 9:00:00         75     7.0015       8         309    317
#
# [468 rows x 11 columns]

# %%
bicis_df.truncate(before='2012-11-19 22:00:00', after='2012-12-01 00:00:00')
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2012-11-19 22:00:00       4        0           1        1  13.94  17.425
# 2012-11-19 23:00:00       4        0           1        1  13.94  17.425
# 2012-11-19 2:00:00        4        0           1        2  14.76  16.665
# 2012-11-19 3:00:00        4        0           1        2  14.76  17.425
# 2012-11-19 4:00:00        4        0           1        2  14.76  17.425
# 2012-11-19 5:00:00        4        0           1        2  14.76  17.425
# 2012-11-19 6:00:00        4        0           1        2  14.76  16.665
# 2012-11-19 7:00:00        4        0           1        2  14.76  16.665
# 2012-11-19 8:00:00        4        0           1        2  14.76  16.665
# 2012-11-19 9:00:00        4        0           1        2  14.76  16.665
#
#                      humidity  windspeed  casual  registered  count
# datetime
# 2012-11-19 22:00:00        66     7.0015       7         106    113
# 2012-11-19 23:00:00        66     7.0015       2          72     74
# 2012-11-19 2:00:00         66    16.9979       0           5      5
# 2012-11-19 3:00:00         66    15.0013       0           2      2
# 2012-11-19 4:00:00         66    15.0013       1          11     12
# 2012-11-19 5:00:00         66    15.0013       1          38     39
# 2012-11-19 6:00:00         66    16.9979       3         128    131
# 2012-11-19 7:00:00         66    19.9995       5         381    386
# 2012-11-19 8:00:00         66    19.9995      13         650    663
# 2012-11-19 9:00:00         66    16.9979      18         260    278

# %% [markdown]
# ### `dt` accessor

# %%
# Permite obtener propiedades de tipo fecha de una Series
fechas_series = pd.Series(pd.date_range('2020-09-30 00:00:41', periods=3, freq='s'))
fechas_series
# Out:
# 0   2020-09-30 00:00:41
# 1   2020-09-30 00:00:42
# 2   2020-09-30 00:00:43
# dtype: datetime64[ns]

# %%
fechas_series.dt.second
# Out:
# 0    41
# 1    42
# 2    43
# dtype: int64

# %%
fechas_series = pd.date_range(
    start='04/12/2021', end='04/18/2021', freq='D'
).to_series()
fechas_series.dt.dayofweek
# Out:
# 2021-04-12    0
# 2021-04-13    1
# 2021-04-14    2
# 2021-04-15    3
# 2021-04-16    4
# 2021-04-17    5
# 2021-04-18    6
# Freq: D, dtype: int64

# %% [markdown]
# # Cómo seguir
#
# La documentación oficial es excelente. Un buen repaso es [10 minutes to pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html) y para profundizar, los links de la izquierda.
